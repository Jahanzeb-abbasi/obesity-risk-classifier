# %% [markdown]
# ### 02 - Model Training

# %%
import joblib

data = joblib.load("../artifacts/preprocessed_data.joblib")

# %%
X_rf_train = data["X_rf_train"]
X_rf_test = data["X_rf_test"]
X_logreg_train = data["X_logreg_train"]
X_logreg_test = data["X_logreg_test"]
y_train = data["y_train"]
y_test = data["y_test"]
scaler = data["scaler"]
feature_cols = data["feature_cols"]
